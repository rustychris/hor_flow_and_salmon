# %%
from stompy.model.suntans import sun_driver
import matplotlib.pyplot as plt

# %%
model=sun_driver.SuntansModel.load('runs/cfg006_20180310_20180310/')

# %%
bc_ds=model.load_bc_ds()

# %%
plt.figure()
plt.plot(bc_ds.time,
         bc_ds.h.values)
None

# %%
bc_ds.h.values
# Out:
# array([[1.362456, 1.362456, 1.362456, ..., 1.362456, 1.362456, 1.362456],
#        [1.34112 , 1.34112 , 1.34112 , ..., 1.34112 , 1.34112 , 1.34112 ],
#        [1.322832, 1.322832, 1.322832, ..., 1.322832, 1.322832, 1.322832],
#        ...,
#        [2.304288, 2.304288, 2.304288, ..., 2.304288, 2.304288, 2.304288],
#        [2.310384, 2.310384, 2.310384, ..., 2.310384, 2.310384, 2.310384],
#        [2.31648 , 2.31648 , 2.31648 , ..., 2.31648 , 2.31648 , 2.31648 ]])

# %%
ls
# Out:
# add_bathy.py                  hor_snubby_steady2d.py
# add_bathy.py~                 hor_sun.py
# add_depth_avg.py              local_config.py
# cache/                        local_config.py~
# calibration.ipynb             local_config.py.in
# centerline_velocity_2018.png  log.cfg004-out
# check_advection.py            model-extracted-surf_velocities.png
# check_crash_3d.py             model-extracted-surf_vorticity.png
# check_depths.py               model-extracted-velocities.png
# check_nut_profile.py          model-extracted-vorticity.png
# check_section_fluxes.ipynb    plot_advection.py
# check_stage_bcs.ipynb         plot_bernoulli_3d.py
# compare_ic.py                 plot_bernoulli_plan.py
# compare_vel_profiles.py       plot_bernoulli.py
# dev_shear_vorticity.ipynb     plot_grid_sources.py
# diagnose_crash.py             plot_stmp.py
# extract_velocities.py         plot_transects.py
# extract_velocities_v2.py      plot_transects.py~
# ...
