# %%
from stompy.grid import unstructured_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ls /opt2/san_joaquin/cfg008
# Out:
# cfg008_20180310/  cfg008_20180320/  cfg008_20180330/  cfg008_20180409/  ptm.grd

# %%
grd=unstructured_grid.PtmGrid('/opt2/san_joaquin/cfg008/ptm.grd')
# Out:
# Reading vertices
# Reading polygons
# Reading sides

# %%
plt.figure()
plt.colorbar(grd.plot_cells(values=grd.cells['depth']))
plt.axis('off')
plt.axis('equal')
# Out:
# (646786.6675765, 648104.0773735, 4185415.49187, 4186223.74393)

# %%
plt.figure()
plt.colorbar(grd.plot_edges(values=grd.edges['depth']))
plt.axis('off')
plt.axis('equal')
# Out:
# (646786.6675765, 648104.0773735, 4185415.49187, 4186223.74393)

# %%
plt.figure()
plt.colorbar(grd.plot_edges(values=g.edges['Mesh2_edge_depth']))
plt.axis('off')
plt.axis('equal')
# Out:
# (646786.6675765, 648104.0773735, 4185415.49187, 4186223.74393)

# %%
grd.edges
# Out:
# array([([ 4431,  9646], -99, [-1, -1], False, 6.892887 ),
#        ([ 9646,  7641], -99, [-1, -1], False, 6.892887 ),
#        ([ 7641,  9755], -99, [-1, -1], False, 6.341456 ), ...,
#        ([13019, 13020], -99, [-1, -1], False, 0.2757155),
#        ([ 8001, 13020], -99, [-1, -1], False, 0.2757155),
#        ([13020,  9354], -99, [-1, -1], False, 0.2757155)],
#       dtype=[('nodes', '<i4', (2,)), ('mark', '<i4'), ('cells', '<i4', (2,)), ('deleted', '?'), ('depth', '<f8')])

# %%
grd.cells
# Out:
# array([([    3,     0,     1,     2], [ 4431,  9646,  7641,  9755], [nan, nan], 0, nan, False, 6.892887 ),
#        ([    7,     4,     5,     6], [ 8449,  9117,  7815,  8512], [nan, nan], 0, nan, False, 0.2757155),
#        ([   11,     8,     9,    10], [ 9176,  9822,  8359,  9818], [nan, nan], 0, nan, False, 2.481439 ),
#        ...,
#        ([ 7681, 25739, 25738,    -1], [ 9354, 13020,  8001,    -1], [nan, nan], 0, nan, False, 0.2757155),
#        ([   46,    43, 25737, 25736], [ 5397, 13019, 13020,  2576], [nan, nan], 0, nan, False, 0.2757155),
#        ([   44,    45, 25737, 25734], [ 6932, 13020, 13019,  7854], [nan, nan], 0, nan, False, 0.2757155)],
#       dtype=[('edges', '<i4', (4,)), ('nodes', '<i4', (4,)), ('_center', '<f8', (2,)), ('mark', '<i4'), ('_area', '<f8'), ('deleted', '?'), ('depth', '<f8')])

# %%
g=unstructured_grid.UnstructuredGrid.from_ugrid('/opt2/san_joaquin/cfg008/cfg008_20180310/ptm_average.nc_0000.nc',
                                               dialect='fishptm')

# %%
plt.figure()
plt.colorbar(g.plot_cells(values=g.cells['Mesh2_face_depth']))
plt.axis('off')
plt.axis('equal')
# Out:
# (646786.6675765, 648104.0773735, 4185415.49187, 4186223.74393)

# %%
plt.figure()
plt.colorbar(g.plot_edges(values=g.edges['Mesh2_edge_depth']))
plt.axis('off')
plt.axis('equal')
# Out:
# (646786.6675765, 648104.0773735, 4185415.49187, 4186223.74393)

# %%
g.edges
# Out:
# array([([ 4431,  9646], -99, [-99, -99], False, 0., 6.892887 ),
#        ([ 9646,  7641], -99, [-99, -99], False, 0., 6.892887 ),
#        ([ 7641,  9755], -99, [-99, -99], False, 0., 6.341456 ), ...,
#        ([13019, 13020], -99, [-99, -99], False, 0., 0.2757155),
#        ([ 8001, 13020], -99, [-99, -99], False, 0., 0.2757155),
#        ([13020,  9354], -99, [-99, -99], False, 0., 0.2757155)],
#       dtype=[('nodes', '<i4', (2,)), ('mark', '<i4'), ('cells', '<i4', (2,)), ('deleted', '?'), ('Mesh2_edge_bc', '<f8'), ('Mesh2_edge_depth', '<f8')])

# %%
g.cells
# Out:
# array([([-99, -99, -99, -99], [ 9755,  4431,  9646,  7641], [ 647098.68129, 4185854.3021 ], 0, nan, False, 6.892887 , 0., -6.892887 ),
#        ([-99, -99, -99, -99], [ 8512,  8449,  9117,  7815], [ 647500.0962 , 4186065.8508 ], 0, nan, False, 0.2757155, 0., -0.2757155),
#        ([-99, -99, -99, -99], [ 9818,  9176,  9822,  8359], [ 647485.53121, 4186063.4839 ], 0, nan, False, 2.481439 , 0., -2.481439 ),
#        ...,
#        ([-99, -99, -99, -99], [ 8001,  9354, 13020,    -1], [ 647158.00577, 4185816.6147 ], 0, nan, False, 0.2757155, 0., -0.2757155),
#        ([-99, -99, -99, -99], [ 2576,  5397, 13019, 13020], [ 647162.20386, 4185815.2264 ], 0, nan, False, 0.2757155, 0., -0.2757155),
#        ([-99, -99, -99, -99], [ 7854,  6932, 13020, 13019], [ 647162.43337, 4185816.9817 ], 0, nan, False, 0.2757155, 0., -0.2757155)],
# ...
